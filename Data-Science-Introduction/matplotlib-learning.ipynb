# %% [markdown]
# <h1 align='center'>Matplotlib</h1>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# <h4> plot </h4>
# plot with X and Y can be used to plot the equation and graph distribution

# %%
X=[0,1,2,3,4,5]
Y=[0,1,2,3,4,5]
plt.plot(X,Y)

# %%
#x2=4*ay
#y=x2/(4a)

def parabola_plot(x,a=1):
    y=[i**2/(4*a) for i in x]
    return y

X=[-3,-2,-1,0,1,2,3]
Y=parabola_plot(X)
plt.plot(X,Y)
display(X,Y)
# Out:
# [-3, -2, -1, 0, 1, 2, 3]
# [2.25, 1.0, 0.25, 0.0, 0.25, 1.0, 2.25]

# %% [markdown]
# <h3> Scatter plot </h3>

# %%
import random
physics_marks=[random.randrange(1,100) for i in range(1,100)]
mathematics_marks=[random.randrange(1,100) for i in range(1,100)]
plt.scatter(physics_marks,mathematics_marks)
plt.xlabel('Physics')
plt.ylabel('Mathematics')
# Out:
# Text(0, 0.5, 'Mathematics')
